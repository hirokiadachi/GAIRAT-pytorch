# %%
# %run -i main.py --checkpoint ./checkpoint/cifar10/wideresnet_random_start --model WRN --epochs 100 --gpu 0,1,2,3
# Out:
# Namespace(alpha=2, batch_size=128, burn_in_period=60, checkpoint='./checkpoint/cifar10/wideresnet_random_start', epochs=100, epsilon=8, gpu='0,1,2,3', lam=-1, lr=0.1, model='WRN', momentum=0.9, num_classes=10, num_iters=10, weight_decay=0.0005)
# Files already downloaded and verified
# Files already downloaded and verified
# 0 epoch [0/391] | loss: 3.2106 (avg: 0.0251) | acc: 0.0000 (avg: 0.0000)
# 0 epoch [100/391] | loss: 2.2501 (avg: 0.0182) | acc: 0.1797 (avg: 0.1350)
# 0 epoch [200/391] | loss: 2.0629 (avg: 0.0176) | acc: 0.2500 (avg: 0.1595)
# 0 epoch [300/391] | loss: 2.0570 (avg: 0.0172) | acc: 0.2344 (avg: 0.1779)
# Validation | nat acc: 0.3330 | adv acc: 0.2330
# Current model achieved the best accuracy, so saved as the best model.
# 1 epoch [0/391] | loss: 2.0012 (avg: 0.0156) | acc: 0.2188 (avg: 0.2188)
# 1 epoch [100/391] | loss: 1.9756 (avg: 0.0158) | acc: 0.2109 (avg: 0.2409)
# 1 epoch [200/391] | loss: 2.1168 (avg: 0.0158) | acc: 0.2188 (avg: 0.2425)
# ...

# %%
# %run -i evaluation.py --gpu 0,1,2,3 --checkpoint checkpoint/cifar10/wideresnet_random_start/model --model WRN
# Out:
# Namespace(alpha=2, batch_size=128, checkpoint='checkpoint/cifar10/wideresnet_random_start/model', epsilon=8, gpu='0,1,2,3', model='WRN', num_classes=10, num_iters=20, num_restart=1)
# Files already downloaded and verified
# Test accuracy (natural samples): 0.8407
# Test robust accuracy (PGD attack): 0.5233

# %% [markdown]
# ||Clean|PGD20 (non-restart)|PGD20 (5restart)|
# |:---:|:---:|:---:|:---:|
# |Best|83.69|54.98|55.00|
# |Last|84.07|52.33|52.36|
